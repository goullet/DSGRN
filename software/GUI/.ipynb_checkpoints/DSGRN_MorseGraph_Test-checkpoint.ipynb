# %%
import DSGRN_Database as dsgrnDB
import DSGRN_General_Information as dsgrnGI
import DSGRN_Graphviz as dsgrnGV
import DSGRN_Query as dsgrnQY
from ipywidgets import widgets
from IPython.display import display

# %%
connector = dsgrnDB.connect("2D_Example_A.db")

# %%
MGgv = dsgrnDB.getAllMorseGraphGV(connector)

# %%
def displayAllMG(MG):
    for i in range(len(MG)):
        print("MorseGraph="+str(MG[i][0]))
        display(dsgrnGV.display_gv(str(MG[i][1])))

# %%
displayAllMG(MGgv)
# Out:
# MorseGraph=0
# MorseGraph=1
# MorseGraph=2
# MorseGraph=3
# MorseGraph=4
# MorseGraph=5
# MorseGraph=6
# MorseGraph=7
# MorseGraph=8
# MorseGraph=9
# MorseGraph=10
# MorseGraph=11
# MorseGraph=12
# MorseGraph=13
# MorseGraph=14
# MorseGraph=15
# MorseGraph=16
# MorseGraph=17
