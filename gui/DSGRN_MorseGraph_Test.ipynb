# %%
import DSGRN_Database as dsgrnDB
import DSGRN_General_Information as dsgrnGI
import DSGRN_Graphviz as dsgrnGV
import DSGRN_Query as dsgrnQY
from ipywidgets import widgets
from IPython.display import display

# %%
connector = dsgrnDB.connect("2D_Example_A.db")

# %%
MGgv = dsgrnDB.getAllMorseGraphGV(connector)

# %%
len(MGgv)
# Out:
# 18

# %%
def displayAllMG(MG):
    for i in range(len(MG)):
        print(str(MG[i][1]))
#         dsgrnGV.display_gv(str(MG[i][1])
    
displayAllMG(MGgv)
# Out:
# digraph {
# 0[label="FP"];
# 1[label="FP ON"];
# }
#
# digraph {
# 0[label="FP ON"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP ON"];
# 2[label="FP ON"];
# }
#
# digraph {
# 0[label="FP ON"];
# 1[label="FP ON"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP OFF"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP"];
# 2[label="FP OFF"];
# 3[label="FP ON"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP OFF"];
# 2[label="FP ON"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP"];
# 2[label="FP OFF"];
# 3[label="FP ON"];
# 4[label="FP ON"];
# }
#
# digraph {
# 0[label="FP"];
# }
#
# digraph {
# 0[label="FP OFF"];
# 1[label="FP ON"];
# }
#
# digraph {
# 0[label="FP OFF"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP"];
# 2[label="FP ON"];
# 3[label="FP ON"];
# }
#
# digraph {
# 0[label="FP OFF"];
# 1[label="FP ON"];
# 2[label="FP ON"];
# }
#
# digraph {
# 0[label="FP"];
# 1[label="FP OFF"];
# 2[label="FP ON"];
# ...

# %%
dsgrnGV.display_gv(str(MGgv[0][1]))
dsgrnGV.display_gv(str(MGgv[10][1]))

# %%
gv1=widgets.Box([dsgrnGV.display_gv(str(MGgv[0][1]))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-9b5ca8dc816e> in <module>()
# ----> 1 gv1=widgets.Box([dsgrnGV.display_gv(str(MGgv[0][1]))])
#       2
#
# /Users/arnaud/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget_box.pyc in __init__(self, children, **kwargs)
#      39     def __init__(self, children = (), **kwargs):
#      40         kwargs['children'] = children
# ---> 41         super(Box, self).__init__(**kwargs)
#      42         self.on_displayed(Box._fire_children_displayed)
#      43
#
# /Users/arnaud/anaconda/lib/python2.7/site-packages/ipywidgets/widgets/widget.pyc in __init__(self, *pargs, **kwargs)
#     503
#     504     def __init__(self, *pargs, **kwargs):
# --> 505         super(DOMWidget, self).__init__(*pargs, **kwargs)
#     506
#     507         def _validate_border(name, old, new):
#
# ...
